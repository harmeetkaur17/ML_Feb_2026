# %%
st= input("Enter your input:") 

print("The input is:", st) 

  

st= input("Enter your input:") 

print("The input is:", st)
# Out:
# The input is: hello harmeet
# The input is: 2+3+4

# %%
st= raw_input("Enter your input:") 

print("The input is:", st) 

 

st= input("Enter your input:") 

print("The input is:", st)

# %%
open("first.txt", "r") ## open a file in read mode 

open("hello.txt","w")  ## open a file in write mode
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 open("first.txt", "r") ## open a file in read mode
#       3 open("hello.txt","w")  ## open a file in write mode
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'first.txt'

# %%
file=open("first.txt", "w") 

print("file.closed:", file.closed) 

print("file.mode:", file.mode) 

print("file.name:", file.name)
# Out:
# file.closed: False
# file.mode: w
# file.name: first.txt

# %%
file=open("hello.txt", "r") 

print("file.closed=", file.closed) 

file.close() 

print("file.closed=", file.closed)
# Out:
# file.closed= False
# file.closed= True

# %%
file=open("first.txt","r") 

out=file.read() ## read the 8 bytes of the file   

print("The data in the file is:", out) 

file.close()
# Out:
# The data in the file is: Hello everyone!!
#
# Welcome to the Robogarden Course.

# %%
file=open("first.txt","r") 

file_lines=file.readlines() # return a list of file lines 

print("length of file lines is:", len(file_lines)) 

for line in file_lines: 

    print("The file line is:", line) 

  

file.close()
# Out:
# length of file lines is: 3
# The file line is: Hello everyone!!
#
# The file line is:
#
# The file line is: Welcome to the Robogarden Course.

# %%
file=open("first2.txt","w") 

file.write("Hello students!!\nWelcome to the Robogarden course.") 

file.close()

# %%
file=open("first.txt","r") 

chunk_out= file.read(8) ## read the 8 bytes of the file   

print("chunk_out=", chunk_out) 

current_pose=file.tell() 

print("current_pose=", current_pose) 

  

## return the pointer to the first position of the file again  

file.seek(0,0)  ## offset=0 (number of movements after fromwhere is 0) and fromwhere=0 (first position) 

#read the first 8 bytes again 

chunk_out= file.read(8) ## read the 8 bytes of the file   

print("chunk_out=", chunk_out) 

  

file.close()
# Out:
# chunk_out= Hello ev
# current_pose= 8
# chunk_out= Hello ev
